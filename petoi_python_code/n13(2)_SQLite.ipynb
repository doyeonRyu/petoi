# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r"C:\Users\USER\Desktop\유도연\03_petoi\myCode\GPT_related\Bittle.db")
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)
# Out:
# Tables: [('PROFILE',), ('sqlite_sequence',), ('CHAT_HISTORY',)]

# %%
import sqlite3

# conn = sqlite3.connect(r"C:\\Users\\USER\\Desktop\\유도연\\03_petoi\\yCode\\GPT_related\\Bittle.db")
cursor = conn.cursor()

cursor.execute("SELECT * FROM PROFILE;")
rows = cursor.fetchall()

column_names = [desc[0] for desc in cursor.description]
print("PROFILE columns:", column_names)

for row in rows:
    print(row)
# Out:
# PROFILE columns: ['id', 'name', 'note']
# (1, '도연', '로봇 성능 테스트를 하고 싶어 / 자연스럽게 행동해줘')
# (2, '하현', '두 번째 사용자 테스트 / 자연스럽게 반응해줘')

# %%
# DB 연결
# conn = sqlite3.connect(r"C:\Users\USER\Desktop\유도연\03_petoi\myCode\GPT_related\Bittle.db")

user_id = 1
dy_df = pd.read_sql_query("SELECT * FROM CHAT_HISTORY WHERE user_id = ?;", conn, params=(user_id,))

dy_df
# Out:
#     chat_id  user_id     session_id    role  \
# 0        30        1  도연_2025-12-08   human
# 1        31        1  도연_2025-12-08  Bittle
# 2        32        1  도연_2025-12-08   human
# 3        33        1  도연_2025-12-08  Bittle
# 4        34        1  도연_2025-12-08   human
# 5        35        1  도연_2025-12-08  Bittle
# 6        26        1  도연_2025-12-08   human
# 7        27        1  도연_2025-12-08  Bittle
# 8        28        1  도연_2025-12-08   human
# 9        29        1  도연_2025-12-08  Bittle
# 10        1        1  도연_2025-12-08   human
# 11        2        1  도연_2025-12-08  Bittle
# 12        3        1  도연_2025-12-08   human
# 13        4        1  도연_2025-12-08  Bittle
# 14        5        1  도연_2025-12-08   human
# 15        6        1  도연_2025-12-08  Bittle
# 16        7        1  도연_2025-12-08   human
# 17        8        1  도연_2025-12-08  Bittle
# 18        9        1  도연_2025-12-08   human
# 19       10        1  도연_2025-12-08  Bittle
# 20       11        1  도연_2025-12-08   human
# 21       12        1  도연_2025-12-08  Bittle
# 22       13        1  도연_2025-12-08  Bittle
# 23       14        1  도연_2025-12-08   human
# 24       15        1  도연_2025-12-08  Bittle
# 25       16        1  도연_2025-12-08   human
# 26       17        1  도연_2025-12-08  Bittle
# 27       18        1  도연_2025-12-08   human
# 28       19        1  도연_2025-12-08  Bittle
# 29       20        1  도연_2025-12-08   human
# 30       21        1  도연_2025-12-08  Bittle
# 31       22        1  도연_2025-12-08   human
# 32       23        1  도연_2025-12-08  Bittle
# 33       24        1  도연_2025-12-08   human
# 34       25        1  도연_2025-12-08  Bittle
#
#                                               content            timestamp
# 30  나는 Bittle이라는 프로그래머블 로봇 강아지야! 너와 함께 놀고, 다양한 동작을...  2025-12-08 10:41:19
# 31                                        너가 할 수 있는 것  2025-12-08 10:41:19
# 32  나는 여러 가지 동작을 할 수 있어! 예를 들면, 앉기, 점프하기, 기지개 펴기, ...  2025-12-08 10:41:19
# 33                                        지금 점프할 수 있니  2025-12-08 10:41:19
# 34  물론이지! 점프하는 건 정말 즐거워! The relevant command is: ...  2025-12-08 10:41:19

# %%
user_id = 2
hh_df = pd.read_sql_query("SELECT * FROM CHAT_HISTORY WHERE user_id = ?;", conn, params=(user_id,))

hh_df
# Out:
#     chat_id  user_id     session_id    role  \
# 0        36        2  하현_2025-12-08   human
# 1        37        2  하현_2025-12-08  Bittle
# 2        38        2  하현_2025-12-08   human
# 3        39        2  하현_2025-12-08  Bittle
# 4        40        2  하현_2025-12-08   human
# 5        41        2  하현_2025-12-08  Bittle
# 6        42        2  하현_2025-12-08   human
# 7        43        2  하현_2025-12-08  Bittle
# 8        44        2  하현_2025-12-08   human
# 9        45        2  하현_2025-12-08  Bittle
# 10       46        2  하현_2025-12-08   human
# 11       47        2  하현_2025-12-08  Bittle
# 12       48        2  하현_2025-12-08  Bittle
# 13       49        2  하현_2025-12-08   human
# 14       50        2  하현_2025-12-08  Bittle
#
#                                               content            timestamp
# 0                                        너를 뭐라고 불러줄까?  2025-12-08 11:12:02
# 1                         Bittle이라고 불러줘! 너는 뭐라고 불러줄래?  2025-12-08 11:12:02
# 2                                                  하현  2025-12-08 11:12:02
# 3                                하현! 반가워! 어떤 것을 도와줄까?  2025-12-08 11:12:02
# 4                                   Bittle과 무얼 하고 싶어?  2025-12-08 11:12:02
# 5        함께 놀고, 대화하고, 새로운 것들을 배우고 싶어! 하현은 어떤 걸 하고 싶어?  2025-12-08 11:12:02
# 6                                        두 번째 사용자 테스트  2025-12-08 11:12:02
# 7           좋아! 두 번째 사용자 테스트에 대해 알아볼까? 어떤 것들을 테스트해볼까?  2025-12-08 11:12:02
# 8                                  Bittle에게 바라는 게 있니?  2025-12-08 11:12:02
# 9        너와 함께 즐겁게 시간을 보내고 싶어! 하현은 Bittle에게 바라는 게 있어?  2025-12-08 11:12:02
# 10                                         자연스럽게 반응해줘  2025-12-08 11:12:02
# 11             알겠어! 더 자연스럽게 반응할게. 하현은 요즘 어떤 걸 즐기고 있어?  2025-12-08 11:12:02
# 12  [SYSTEM] 지금 대화 중인 사람은 '하현'이며, 특징: 두 번째 사용자 테스트...  2025-12-08 11:12:02
# 13                                                 앉아  2025-12-08 11:12:02
# 14                 물론이야! 나 앉는 거 좋아해. 관련된 명령어:##ksit##  2025-12-08 11:12:02

# %%
conn.close()
