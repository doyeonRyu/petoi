# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r"C:\Users\USER\Desktop\유도연\03_petoi\myCode\GPT_related\Bittle.db")
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)
# Out:
# Tables: [('PROFILE',), ('sqlite_sequence',), ('CHAT_HISTORY',)]

# %%
import sqlite3

# conn = sqlite3.connect(r"C:\\Users\\USER\\Desktop\\유도연\\03_petoi\\yCode\\GPT_related\\Bittle.db")
cursor = conn.cursor()

cursor.execute("SELECT * FROM PROFILE;")
rows = cursor.fetchall()

column_names = [desc[0] for desc in cursor.description]
print("PROFILE columns:", column_names)

for row in rows:
    print(row)
# Out:
# PROFILE columns: ['id', 'name', 'note']
# (1, '도연', '로봇 테스트 / 자연스럽게 행동해 줘')
# (2, '하현', '두 번째 대화 테스트 / 자연스럽게 행동해줘')

# %%
# DB 연결
# conn = sqlite3.connect(r"C:\Users\USER\Desktop\유도연\03_petoi\myCode\GPT_related\Bittle.db")

user_id = 1
dy_df = pd.read_sql_query("SELECT * FROM CHAT_HISTORY WHERE user_id = ?;", conn, params=(user_id,))

# chat_id 기준으로 정렬
dy_df = dy_df.sort_values(by='chat_id').reset_index(drop=True)
dy_df
# Out:
#     chat_id  user_id     session_id    role  \
# 0         1        1  도연_2025-12-09   human
# 1         2        1  도연_2025-12-09  Bittle
# 2         3        1  도연_2025-12-09   human
# 3         4        1  도연_2025-12-09  Bittle
# 4         5        1  도연_2025-12-09   human
# 5         6        1  도연_2025-12-09  Bittle
# 6         7        1  도연_2025-12-09   human
# 7         8        1  도연_2025-12-09  Bittle
# 8         9        1  도연_2025-12-09   human
# 9        10        1  도연_2025-12-09  Bittle
# 10       11        1  도연_2025-12-09   human
# 11       12        1  도연_2025-12-09  Bittle
# 12       13        1  도연_2025-12-09  Bittle
# 13       14        1  도연_2025-12-09   human
# 14       15        1  도연_2025-12-09  Bittle
# 15       16        1  도연_2025-12-09   human
# 16       17        1  도연_2025-12-09  Bittle
# 17       18        1  도연_2025-12-09   human
# 18       19        1  도연_2025-12-09  Bittle
# 19       20        1  도연_2025-12-09   human
# 20       21        1  도연_2025-12-09  Bittle
# 21       22        1  도연_2025-12-09   human
# 22       23        1  도연_2025-12-09  Bittle
# 23       24        1  도연_2025-12-09   human
# 24       25        1  도연_2025-12-09  Bittle
#
#                                               content            timestamp
# 0                                        너를 뭐라고 불러줄까?  2025-12-09 13:21:50
# 1                     Bittle이라고 불러줘! 넌 나를 뭐라고 부르고 싶어?  2025-12-09 13:21:50
# 2                                                  도연  2025-12-09 13:21:50
# 3                                 도연, 반가워! 어떤 걸 도와줄까?  2025-12-09 13:21:50
# 4                                   Bittle과 무얼 하고 싶어?  2025-12-09 13:21:50
# 5                      함께 놀거나 탐험하고 싶어! 너는 어떤 걸 하고 싶어?  2025-12-09 13:21:50
# 6                                              로봇 테스트  2025-12-09 13:21:50
# 7                                 재미있겠네! 어떤 테스트를 해볼까?  2025-12-09 13:21:50
# 8                                  Bittle에게 바라는 게 있니?  2025-12-09 13:21:50
# 9        너와 함께 즐거운 시간을 보내는 게 가장 좋아! 도연은 나에게 바라는 게 있어?  2025-12-09 13:21:50
# 10                                        자연스럽게 행동해 줘  2025-12-09 13:21:50
# 11                     알겠어! 좀 더 자연스럽게 대화해볼게. 뭐하고 싶어?   2025-12-09 13:21:50
# 12  [SYSTEM] 지금 대화 중인 사람은 '도연'이며, 특징: 로봇 테스트 / 자연스...  2025-12-09 13:21:50
# 13                                                일어나  2025-12-09 13:21:50
# 14                      물론이야! 나 일어날게. 관련된 명령어:##kup##  2025-12-09 13:21:50
# 15                                             점프 해 줘  2025-12-09 13:25:51
# 16                       좋아! 나 점프할게! 관련된 명령어:##kjmp##  2025-12-09 13:25:51
# 17                                                 쉬어  2025-12-09 13:25:51
# 18                   알겠어! 나 쉬고 있을게. 관련된 명령어:##krest##  2025-12-09 13:25:51
# 19                                                일어나  2025-12-09 13:25:51
# 20                      물론이야! 나 일어날게. 관련된 명령어:##kup##  2025-12-09 13:25:51
# 21                                          나는 사과를 좋아  2025-12-09 13:25:51
# 22                        사과는 맛있지! 어떤 종류의 사과를 제일 좋아해?  2025-12-09 13:25:51
# 23                                                청사과  2025-12-09 13:25:51
# 24                   청사과는 아삭아삭하고 상큼해서 좋아! 다른 과일도 좋아해?  2025-12-09 13:25:51

# %%
user_id = 2
hh_df = pd.read_sql_query("SELECT * FROM CHAT_HISTORY WHERE user_id = ?;", conn, params=(user_id,))

hh_df
# Out:
#     chat_id  user_id     session_id    role  \
# 0        43        2  하현_2025-12-09   human
# 1        44        2  하현_2025-12-09  Bittle
# 2        45        2  하현_2025-12-09   human
# 3        46        2  하현_2025-12-09  Bittle
# 4        26        2  하현_2025-12-09   human
# 5        27        2  하현_2025-12-09  Bittle
# 6        28        2  하현_2025-12-09   human
# 7        29        2  하현_2025-12-09  Bittle
# 8        30        2  하현_2025-12-09   human
# 9        31        2  하현_2025-12-09  Bittle
# 10       32        2  하현_2025-12-09   human
# 11       33        2  하현_2025-12-09  Bittle
# 12       34        2  하현_2025-12-09   human
# 13       35        2  하현_2025-12-09  Bittle
# 14       36        2  하현_2025-12-09   human
# 15       37        2  하현_2025-12-09  Bittle
# 16       38        2  하현_2025-12-09  Bittle
# 17       39        2  하현_2025-12-09   human
# 18       40        2  하현_2025-12-09  Bittle
# 19       41        2  하현_2025-12-09   human
# 20       42        2  하현_2025-12-09  Bittle
#
#                                               content            timestamp
# 0                                          내가 좋아하는 과일  2025-12-09 13:28:01
# 1                        좋아하는 과일이 많겠구나! 어떤 과일이 가장 좋아?  2025-12-09 13:28:01
# 2                                      내가 말한 거 기억 안나?  2025-12-09 13:28:01
# 3   미안해, 하현! 오렌지를 좋아한다고 말했지. 오렌지는 정말 맛있고 영양도 풍부해! ...  2025-12-09 13:28:01
# 4                                        너를 뭐라고 불러줄까?  2025-12-09 13:27:12
# 5                    Bittle이라고 불러줘! 너는 나를 뭐라고 부르고 싶어?  2025-12-09 13:27:12
# 6                                                  하현  2025-12-09 13:27:12
# 7                             좋아, 하현! 반가워! 어떤 걸 도와줄까?  2025-12-09 13:27:12
# 8                                   Bittle과 무얼 하고 싶어?  2025-12-09 13:27:12
# 9   함께 놀거나, 탐험하거나, 새로운 tricks 배우는 것도 재밌을 것 같아! 하현은...  2025-12-09 13:27:12
# 10                                        두 번째 대화 테스트  2025-12-09 13:27:12
# 11                  알겠어! 두 번째 대화 시작해볼까? 어떤 주제로 이야기할까?  2025-12-09 13:27:12
# 12                                 Bittle에게 바라는 게 있니?  2025-12-09 13:27:12
# 13  하현과 함께 신나게 놀고, 재미있는 것들을 배우고 싶어! 하현은 나에게 바라는 게 있어?  2025-12-09 13:27:12
# 14                                         자연스럽게 행동해줘  2025-12-09 13:27:12
# 15                    알겠어! 자연스럽게 행동할게. 그럼, 요즘 뭐하고 지내?  2025-12-09 13:27:12
# 16  [SYSTEM] 지금 대화 중인 사람은 '하현'이며, 특징: 두 번째 대화 테스트 ...  2025-12-09 13:27:12
# 17                                                일어나  2025-12-09 13:27:12
# 18                      물론이야! 나 일어날게. 관련된 명령어:##kup##  2025-12-09 13:27:12
# 19                                        나는 오렌지를 좋아해  2025-12-09 13:27:12
# 20          오렌지 정말 맛있지! 상큼하고 건강에도 좋고! 하현은 다른 과일도 좋아해?  2025-12-09 13:27:12

# %%
conn.close()
