# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("C:\\Users\\USER\\Desktop\\유도연\\petoi\\코드정리\\페토이_기본_코드_정리\\Bittle.db")  
cur = conn.cursor()

profile_df = pd.read_sql_query("SELECT * FROM PROFILE", conn)

# %%
profile_df
# Out:
#    id name         note
# 0   1   도연
# 1   2   하현  로봇 테스트 / 친구
# 2   3   서연           /

# %%
dy_chat_df = pd.read_sql_query(
    "SELECT * FROM CHAT_HISTORY WHERE user_id = ?", 
    conn, 
    params=(1,)
)
hh_chat_df = pd.read_sql_query(
    "SELECT * FROM CHAT_HISTORY WHERE user_id = ?", 
    conn, 
    params=(2,)
)
sy_chat_df = pd.read_sql_query(
    "SELECT * FROM CHAT_HISTORY WHERE user_id = ?", 
    conn, 
    params=(3,)
)

# %%
dy_chat_df
# Out:
#     chat_id  user_id     session_id    role  \
# 0         1        1  도연_2025-11-07   human
# 1         2        1  도연_2025-11-07  Bittle
# 2         3        1  도연_2025-11-07   human
# 3         4        1  도연_2025-11-07  Bittle
# 4         5        1  도연_2025-11-07   human
# 5         6        1  도연_2025-11-07  Bittle
# 6         7        1  도연_2025-11-07   human
# 7         8        1  도연_2025-11-07  Bittle
# 8         9        1  도연_2025-11-07   human
# 9        10        1  도연_2025-11-07  Bittle
# 10       11        1  도연_2025-11-07   human
# 11       12        1  도연_2025-11-07  Bittle
#
#                                   content   timestamp
# 0                                      안녕  2025-11-07
# 1           안녕! 나랑 이야기해줘서 반가워! 어떤 걸 도와줄까?  2025-11-07
# 2                                   테스트 1  2025-11-07
# 3                무엇을 테스트하고 싶어? 더 자세히 말해줘!  2025-11-07
# 4                                      잘가  2025-11-07
# 5                        잘가! 다음에 또 이야기하자!  2025-11-07
# 6                                     안녕   2025-11-07
# 7        안녕! 다시 만나서 반가워! 오늘은 어떤 이야기를 나눌까?  2025-11-07
# 8                                    테스트2  2025-11-07
# 9   무엇을 테스트하고 싶은지 말해줘! 도움이 필요하면 언제든지 말해줘!  2025-11-07
# 10                                     잘가  2025-11-07
# 11           잘가! 다음에 또 이야기해! 항상 기다리고 있을게!  2025-11-07

# %%
hh_chat_df
# Out:
#    chat_id  user_id     session_id    role  \
# 0       19        2  하현_2025-11-07   human
# 1       20        2  하현_2025-11-07  Bittle
# 2       21        2  하현_2025-11-07   human
# 3       22        2  하현_2025-11-07  Bittle
#
#                                     content   timestamp
# 0                                        안녕  2025-11-07
# 1       안녕! 나와 이야기해줘서 정말 기뻐! 무슨 이야기를 하고 싶어?  2025-11-07
# 2                                      테스트   2025-11-07
# 3  테스트 잘 하고 있어! 무엇을 테스트 중인지 궁금하네. 더 이야기해줄래?  2025-11-07

# %%
sy_chat_df
# Out:
# Empty DataFrame
# Columns: [chat_id, user_id, session_id, role, content, timestamp]
# Index: []

# %%
conn.close()
